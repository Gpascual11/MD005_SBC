# %% [markdown]
# # Aprendizaje Analógico - KNN
#
#
# El dataset que usaremos para el notebook de ejemplo es el siguiente: [glass dataset](https://archive.ics.uci.edu/dataset/42/glass+identification)
#
# Clasifica 6 tipos de vidrio definidos en términos de su contenido de óxido.

# %% [markdown]
# # Importación librerías

# %%
## Librerías típicas para manejar datos (numpy, pandas y matplotlib)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

## Librería sklearn

### Modeling
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_predict

### Evaluación de resultados para un problema de clasificación
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# # Carga de datos

# %%
df= pd.read_csv('glass.csv')
df

# %%
df.info()

# %%
type_count = df['Type'].value_counts()
df_type = type_count.to_frame()

# %%
df_type['count'].plot(kind='bar', color='skyblue')
plt.title('Type Count')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
# 1. Correlation
# sb.pairplot( ? )

# %% [markdown]
# ## Implementación KNN

# %%
# 2. Separar en atributos (X) y etiquetas (y)
# y =
# df_raw =
# df.drop( ? )

# %%
df

# %%
plt.figure(figsize = (15, 10))
plt.title("Glass dataset boxplots")
df.boxplot(grid=False, rot=45, fontsize=15)
plt.show()

# %%
# 3. Features standardization
# scaler = ?
# scaler.fit(df)
# X_scaled = ?

# %%
# 4. Dividir en train y test
# X_train, X_test, y_train, y_test = ?

print("Tamaño dataset entrenamiento:", X_train.shape)
print("Tamaño dataset validación:", X_test.shape)

# %%
# K values
k_values = [2, 4, 6]

# Saving results
precisions = []
confusion_matrices = []

# 5. Cross validation w/ diff K values
for k in k_values:
    # knn = ?

    # 5-Fold Stratified Cross-Validation
    # cv = ?
    # y_pred = ?

    # Confusion matrices
    # cm = ?
    # confusion_matrices.append(cm)

    # Precision
    # precision = ?
    # precisions.append(precision)

# Print results
for k, precision, cm in zip(k_values, precisions, confusion_matrices):
    print(f"K-value: {k}")
    print("Accuracy:", precision)
    print("Confusion matrix:")
    print(cm)
    print()
    print(classification_report(y_train, y_pred))
    print("="*50)

# %% [markdown]
# ### Parametrización  y entrenamiento de Grid Searh

# %%
# Revisión de los parámetros de entrenamiento
knn.get_params()

# %%
#Probar algunos hiperparámetros
model_params={
    'n_neighbors':[2,4,6]}

# %%
# 6. Grid Search modelo de K-NN
# model = ?
# gscv = ?
# model_gs = ?

print("Best: %f using %s" % (model_gs.best_score_,model_gs.best_params_))

# %% [markdown]
# ### Predicciones con datos de Train

# %%
# 7. Predecir con el modelo
# knn = ?
# knn.fit( ? )
# pred = ?

# pd.DataFrame( ? ).head(10)

# %%
print('Train Confusion Matrix:')
print(confusion_matrix(y_train,pred))
print()
print(classification_report(y_train,pred))

# %% [markdown]
# ### Predicciones con datos de Test

# %%
# pred = ?
# pd.DataFrame( ? ).head(10)

# %%
print('Test Confusion Matrix:')
print(confusion_matrix(y_test,pred))
print()
print(classification_report(y_test,pred))
